# %% [markdown]
# <a href="https://colab.research.google.com/github/AzadMehedi/Python/blob/main/Python_Cheatsheet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. `Python Arithmetic Operators`
# - The Arithmetic Operators in the below table are in Lowest to Highest precedence.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# example of addition
1+3
# Out:
# 4

# %%
# example of subtraction
10-5
# Out:
# 5

# %%
# example of multiplication
2*2
# Out:
# 4

# %%
# example of division
10/3
# Out:
# 3.3333333333333335

# %%
# example of floored division
10//4
# Out:
# 2

# %%
# example of module
3%2
# Out:
# 1

# %% [markdown]
# # 2. `Python Data Types`
# - The table below lists the different data types in Python along with some examples of
# them:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # 3. `Python Variables`
# - Variables are names given to data items that may take on one or more values during a program’s runtime.
# - Following are the variable naming conventions in python:
#   - It cannot begin with a number.
#   - It must be a single word.
#   - It must consist of letters and _ symbols only.
#   - Variables in Python which start with _ (underscore) are considered as “Unuseful”.
#
# Some examples are shown below:

# %%
name = 'Evan'
full_name = 'Evan Azad'
fullName = 'Nafis'
_name= 'fahim'

print(name)
print(full_name)
print(fullName)
print(_name)
# Out:
# Evan
# Evan Azad
# Nafis
# fahim

# %% [markdown]
# # 4. `Python Comments`
# Comments are lines of text/code in the program, which are ignored by the compiler during program execution.
# ### There are multiple types of comments in python:
# - `Inline Comment` :
# We can write an Inline Comment by typing # followed by the comment.
# - `Multiline Comment` :
# We can write a Multiline Comment by typing # followed by the comment in each of
# the lines.
# - `Docstring Comment` :
# Docstring comments are achieved by Typing the comment within triple quotes. ( '''
# comment ''' )

# %%
# inline comment
# this is the inline comment of calculate sum of two numbers
def fun(a, b):
  return a+b

# %%
# miltiline comment

# Multiline
# Comment
# Function to calculate
# sum of 2 numbers
def fun(a, b):
  return a + b

# %%
# docstring comment

'''
This is a function
to find sum
of 2 numbers.
This is an example of
docstring comment.
'''
def fun(a,b):
  return a+b

# %% [markdown]
# # 5. `Standard Python Functions`
# - `print()` function in Python
#   - The print() function prints some specified message to the screen or some standard
# output device. We can print strings, numbers, or any other object using this function.
# We can print multiple tokens, and also specify to print the data separated by different
# delimiters using the print() function

# %%
print('Hellow World')
var = 'We love everything about nature'
print(var)
name = 'Mehedi Azad'
print('May name is',name)
print('May name is ' + name)
print(123)
a = [1,2,3,4,5]
print(a)
# Out:
# Hellow World
# We love everything about nature
# May name is Mehedi Azad
# May name is Mehedi Azad
# 123
# [1, 2, 3, 4, 5]

# %% [markdown]
# - `input()` function in Python
#    - The input() function in Python is used to take any form of inputs from the
# user/standard input device, which can later be processed accordingly in the program.
# It is complementary to the print() function

# %%
print('Enter your Name: ')
name = input()
print('Hellow, {}'.format(name))
# Out:
# Enter your Name:
# Mehedi
# Hellow, Mehedi

# %% [markdown]
#   - `len()` function in Python
#
#     - The len() function is used find the length(number of elements) of any python container like string, list, dictionary, tuple, etc.

# %%
# for list
a = [1,2,3,4,5]
print(len(a))

# for string
a = 'Mehedi'
print(len(a))

# for tuple
a = (1,2,3,4,5,6,7,8)
print(len(a))
# Out:
# 5
# 6
# 8

# %% [markdown]
#    - `ord()` function in Python
#        - The ord() function in Python will return an integer that represents the Unicode Character passed into it. It takes a single character as a parameter.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# print unicode of 'A'
print('Unicode of A is: ', ord('A'))

# Print unicode of '5'
print('Unicode of 5 is: ', ord('5'))

# Print unicode of '$'
print('Unicode of $ is: ', ord('$'))
# Out:
# Unicode of A is:  65
# Unicode of 5 is:  53
# Unicode of $ is:  36

# %% [markdown]
# # 6. `Python Type Casting`
# - Type casting is basically a conversion of variables of a particular datatype into some
# other datatype, such that the conversion is valid.
# - Type casting can be of two types:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
#   ## - `Implicit Type Casting`: In implicit type casting, the python compiler internally typecasts one variable into another type without the external action of the user.

# %%
# implicit tye casting
int_num = 100
float_num = 1.01
ans = int_num + float_num
print(type(int_num))
print(type(float_num))
# ans is implicitly typecasted to float type for greater precision
print(type(ans))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'float'>

# %% [markdown]
# ##  - `Explicit Type Casting`: In explicit type casting, the user explicitly forces the compiler to convert a variable from one type to another. The different ways of explicit typecasting are given below:

# %% [markdown]
# 1. `integer to string or float`: To typecast an integer into a string type, we use the `str()` method. Similarly, to
# typecast it into a float type, we use the `float()` method.

# %%
var = 123
str(var)
# Out:
# 200.0

# %%
a = 200
float(a)
# Out:
# 200.0

# %% [markdown]
# 2. `Float to Integer`: To typecast a float datatype into an integer datatype, we use the `int()` method.

# %%
b = 30.5
int(b)
# Out:
# 30

# %% [markdown]
# # 7. `Program Flow Control in Python`
# - `Relational Operators in Python`:
# The Table gives a list of relational operators available in Python along with their functions:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Equality Operator
print(10 == 10) # 10 is equal to 10, so true
print(10 == '10') # The first string is int type, 2nd of type string, so false.

# grater than
10 > 20  #  10 is lesser than 20, so above expression is false.

#inequality
print(10 != 20)  # 10 is not equal to 20, so the expression is true

# grater than or equal to
print((2+3) >= (4+1))  #  (2 + 3) = 5 and (4 + 1) = 5, so the expression is true.
# Out:
# True
# False
# True
# True

# %% [markdown]
# ### `Note`: Never use relational operators to compare boolean operations. Use `is` or `is not` operators for it.

# %%
print(True is False)
print(True is not False)
# Out:
# False
# True

# %% [markdown]
# # 8. `Boolean Operators in Python`
# The Table gives a list of boolean operators available in Python along with their
# functions:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# `correction`
# `or`: returns True if at least one operands are Ture, else false

# %%
# and operator
print(True and False)
# or operator
print(True or False)
# not operator
print(not False)
# Out:
# False
# True
# True

# %% [markdown]
# # 9. `Conditional Statements in Python`

# %% [markdown]
# ### `if` statements: :
# If statement is a condition statement that will perform some
# operation, if the expression given in it evaluates to true as shown below:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
var = 'good'
if var == 'good':
  print('Same')
# Out:
# Same

# %% [markdown]
# ## `Elif Statements`:
# This statement is used in conjunction with the if statement to
# add some other condition which is evaluated if the condition in if statement
# fails.

# %%
var = 'Bad'
if var == 'good':
  print('same')
elif var != 'good':
  print('Not same')
# Out:
# Not same

# %% [markdown]
# ## `Else Statements`:
# This statement is used to perform some operation, if all the if
# and elif statements evaluates to be false.

# %%
var = 'bad'
if var == 'good':
  print('same')
else:
  print('what whappend?')
# Out:
# what whappend?

# %% [markdown]
# the final if-elif-else ladder looks like shown below

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # 10. `Loop Statements in Python`
